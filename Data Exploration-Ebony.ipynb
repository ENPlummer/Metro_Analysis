# %% [markdown]
# In this section I will be exploring ridership data. The orginal data set is Metrorail ridership from 2010-2016.

# %%
#Dependencies

import pandas as pd

# %%
#2010-2016 Metrorail ridership data 2010-2016.

ridership_data = pd.read_excel('Resources/Avg-Weekday-Rail-Ridership-by-Month-by-Station-2010-to-20161.xlsx')
ridership_data.head()
# Out:
#    DATEMONTHINT                 STATION  RIDERS_PER_WEEKDAY
# 0        201009            Addison Road              3667.3
# 1        201009               Anacostia              7290.0
# 2        201009  Archives-Navy Memorial              9094.8
# 3        201009      Arlington Cemetery              1110.9
# 4        201009                Ballston             12146.5

# %% [markdown]
# Ridership data for 2014.

# %%
ridership_14 = ridership_data[(ridership_data.DATEMONTHINT > 201312) & (ridership_data.DATEMONTHINT <=201412)]
ridership_14.head(20)
# Out:
#       DATEMONTHINT                 STATION  RIDERS_PER_WEEKDAY
# 3450        201401            Addison Road              2763.5
# 3451        201401               Anacostia              6517.2
# 3452        201401  Archives-Navy Memorial              7625.9
# 3453        201401      Arlington Cemetery               321.3
# 3454        201401                Ballston             10629.0
# 3455        201401            Benning Road              2787.1
# 3456        201401                Bethesda              9587.5
# 3457        201401           Braddock Road              4014.8
# 3458        201401           Branch Avenue              5529.2
# 3459        201401               Brookland              6241.5
# 3460        201401         Capitol Heights              1836.0
# 3461        201401           Capitol South              6968.7
# 3462        201401                Cheverly              1305.5
# 3463        201401               Clarendon              4253.4
# ...

# %%
sort_riders_14 = ridership_14.sort_values('RIDERS_PER_WEEKDAY', ascending=False)
sort_riders_14.head(20)
# Out:
#       DATEMONTHINT                  STATION  RIDERS_PER_WEEKDAY
# 3966        201406            Union Station             33797.2
# 3790        201404            Union Station             33671.5
# 4057        201407            Union Station             32419.5
# 3876        201405            Union Station             32365.5
# 4330        201410            Union Station             31532.2
# 4239        201409            Union Station             31445.9
# 3703        201403            Union Station             31306.6
# 3615        201402            Union Station             29949.7
# 4421        201411            Union Station             29934.6
# 3528        201401            Union Station             29303.7
# 4148        201408            Union Station             29272.0
# 3937        201406             Metro Center             29158.5
# 3763        201404             Metro Center             28811.1
# 4028        201407             Metro Center             28636.9
# ...

# %%
#Top 50 records.
top_50_ridership_14 = sort_riders_14.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_ridership_14
# Out:
#       DATEMONTHINT                  STATION  RIDERS_PER_WEEKDAY
# 3966        201406            Union Station             33797.2
# 3790        201404            Union Station             33671.5
# 4057        201407            Union Station             32419.5
# 3876        201405            Union Station             32365.5
# 4330        201410            Union Station             31532.2
# 4239        201409            Union Station             31445.9
# 3703        201403            Union Station             31306.6
# 3615        201402            Union Station             29949.7
# 4421        201411            Union Station             29934.6
# 3528        201401            Union Station             29303.7
# 4148        201408            Union Station             29272.0
# 3937        201406             Metro Center             29158.5
# 3763        201404             Metro Center             28811.1
# 4028        201407             Metro Center             28636.9
# ...

# %%
#Bottom 50 Records.
bottom_50_ridership_14 = sort_riders_14.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_ridership_14
# Out:
#       DATEMONTHINT             STATION  RIDERS_PER_WEEKDAY
# 3666        201403          Greensboro                 0.0
# 3489        201401          Greensboro                 0.0
# 3585        201402              McLean                 0.0
# 3526        201401       Tysons Corner                 1.0
# 3497        201401              McLean                 1.5
# 3760        201404              McLean                 2.0
# 3958        201406         Spring Hill                 2.2
# 3964        201406       Tysons Corner                 3.8
# 3625        201402              Wiehle                 4.0
# 3934        201406              McLean                 4.1
# 3926        201406          Greensboro                 4.3
# 3976        201406              Wiehle                25.6
# 4017        201407          Greensboro               209.2
# 3453        201401  Arlington Cemetery               321.3
# 3542        201402  Arlington Cemetery               336.9
# ...

# %%
metro_stations_14 = sort_riders_14.groupby('STATION')
metro_stations_14.head()
# Out:
#       DATEMONTHINT                  STATION  RIDERS_PER_WEEKDAY
# 3966        201406            Union Station             33797.2
# 3790        201404            Union Station             33671.5
# 4057        201407            Union Station             32419.5
# 3876        201405            Union Station             32365.5
# 4330        201410            Union Station             31532.2
# 3937        201406             Metro Center             29158.5
# 3763        201404             Metro Center             28811.1
# 4028        201407             Metro Center             28636.9
# 3849        201405             Metro Center             27754.0
# 4301        201410             Metro Center             27601.0
# 3749        201404  Gallery Place-Chinatown             26702.2
# 3922        201406  Gallery Place-Chinatown             26635.0
# 4013        201407  Gallery Place-Chinatown             26079.6
# 3913        201406           Farragut North             25868.3
# ...

# %% [markdown]
# Ridership data for 2015.

# %%
ridership_15 = ridership_data[(ridership_data.DATEMONTHINT > 201412) & (ridership_data.DATEMONTHINT <=201512)]
ridership_15.head(20)
# Out:
#       DATEMONTHINT                 STATION  RIDERS_PER_WEEKDAY
# 4524        201501            Addison Road              3056.6
# 4525        201501               Anacostia              6626.4
# 4526        201501  Archives-Navy Memorial              7322.0
# 4527        201501      Arlington Cemetery               418.7
# 4528        201501                Ballston             10801.9
# 4529        201501            Benning Road              2904.7
# 4530        201501                Bethesda              9922.2
# 4531        201501           Braddock Road              4380.2
# 4532        201501           Branch Avenue              5411.4
# 4533        201501               Brookland              6694.1
# 4534        201501         Capitol Heights              1901.1
# 4535        201501           Capitol South              6970.9
# 4536        201501                Cheverly              1231.5
# 4537        201501               Clarendon              4528.0
# ...

# %%
sort_riders_15 = ridership_15.sort_values('RIDERS_PER_WEEKDAY', ascending=False)
sort_riders_15.head(20)
# Out:
#       DATEMONTHINT                  STATION  RIDERS_PER_WEEKDAY
# 5058        201506            Union Station             32517.0
# 4876        201504            Union Station             32313.0
# 5149        201507            Union Station             32048.5
# 4967        201505            Union Station             30789.4
# 5422        201510            Union Station             30571.8
# 4785        201503            Union Station             30530.6
# 4603        201501            Union Station             29126.5
# 4694        201502            Union Station             28904.1
# 5331        201509            Union Station             28666.0
# 4847        201504             Metro Center             28504.9
# 5240        201508            Union Station             28408.8
# 5513        201511            Union Station             28309.2
# 5029        201506             Metro Center             28221.2
# 5120        201507             Metro Center             27962.6
# ...

# %%
#top 50
top_50_ridership_15 = sort_riders_15.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_ridership_15
# Out:
#       DATEMONTHINT                  STATION  RIDERS_PER_WEEKDAY
# 5058        201506            Union Station             32517.0
# 4876        201504            Union Station             32313.0
# 5149        201507            Union Station             32048.5
# 4967        201505            Union Station             30789.4
# 5422        201510            Union Station             30571.8
# 4785        201503            Union Station             30530.6
# 4603        201501            Union Station             29126.5
# 4694        201502            Union Station             28904.1
# 5331        201509            Union Station             28666.0
# 4847        201504             Metro Center             28504.9
# 5240        201508            Union Station             28408.8
# 5513        201511            Union Station             28309.2
# 5029        201506             Metro Center             28221.2
# 5120        201507             Metro Center             27962.6
# ...

# %%
#Bottom 50
bottom_50_ridership_15 = sort_riders_15.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_ridership_15
# Out:
#       DATEMONTHINT             STATION  RIDERS_PER_WEEKDAY
# 4618        201502  Arlington Cemetery               333.5
# 4527        201501  Arlington Cemetery               418.7
# 5528        201512  Arlington Cemetery               563.2
# 5437        201511  Arlington Cemetery               754.1
# 4654        201502          Greensboro               869.7
# 4563        201501          Greensboro               920.8
# 5564        201512          Greensboro               957.5
# 4745        201503          Greensboro               958.6
# 5596        201512         Spring Hill              1036.2
# 5200        201508          Greensboro              1046.0
# 4686        201502         Spring Hill              1056.5
# 5473        201511          Greensboro              1057.8
# 4927        201505          Greensboro              1075.0
# 4836        201504          Greensboro              1078.4
# 5291        201509          Greensboro              1087.4
# ...

# %%
metro_stations_15 = sort_riders_15.groupby('STATION')
metro_stations_15.head(20)
# Out:
#       DATEMONTHINT                  STATION  RIDERS_PER_WEEKDAY
# 5058        201506            Union Station             32517.0
# 4876        201504            Union Station             32313.0
# 5149        201507            Union Station             32048.5
# 4967        201505            Union Station             30789.4
# 5422        201510            Union Station             30571.8
# 4785        201503            Union Station             30530.6
# 4603        201501            Union Station             29126.5
# 4694        201502            Union Station             28904.1
# 5331        201509            Union Station             28666.0
# 4847        201504             Metro Center             28504.9
# 5240        201508            Union Station             28408.8
# 5513        201511            Union Station             28309.2
# 5029        201506             Metro Center             28221.2
# 5120        201507             Metro Center             27962.6
# ...

# %% [markdown]
# Ridership data for 2016.

# %%
ridership_16 = ridership_data[(ridership_data.DATEMONTHINT > 201512) & (ridership_data.DATEMONTHINT <=201612)]
ridership_16.head(20)
# Out:
#       DATEMONTHINT                 STATION  RIDERS_PER_WEEKDAY
# 5616        201601            Addison Road              2531.9
# 5617        201601               Anacostia              5959.8
# 5618        201601  Archives-Navy Memorial              6982.2
# 5619        201601      Arlington Cemetery               353.9
# 5620        201601                Ballston              9722.7
# 5621        201601            Benning Road              2445.3
# 5622        201601                Bethesda              8990.9
# 5623        201601           Braddock Road              4298.4
# 5624        201601           Branch Avenue              4716.8
# 5625        201601               Brookland              5700.5
# 5626        201601         Capitol Heights              1693.4
# 5627        201601           Capitol South              5788.5
# 5628        201601                Cheverly              1018.7
# 5629        201601               Clarendon              4084.5
# ...

# %%
sort_riders_16 = ridership_16.sort_values('RIDERS_PER_WEEKDAY', ascending=False)
sort_riders_16.head(20)
# Out:
#       DATEMONTHINT                  STATION  RIDERS_PER_WEEKDAY
# 5786        201602            Union Station             29370.6
# 5742        201602  Gallery Place-Chinatown             25537.3
# 5695        201601            Union Station             25384.9
# 5733        201602           Farragut North             24597.0
# 5757        201602             Metro Center             24329.8
# 5651        201601  Gallery Place-Chinatown             22386.3
# 5642        201601           Farragut North             21596.2
# 5666        201601             Metro Center             21568.6
# 5734        201602            Farragut West             20917.1
# 5737        201602             Foggy Bottom             20120.8
# 5751        201602           L'Enfant Plaza             19342.6
# 5729        201602            Dupont Circle             18653.1
# 5643        201601            Farragut West             18297.8
# 5646        201601             Foggy Bottom             17861.0
# ...

# %%
#Top 50
top_50_ridership_16 = sort_riders_16.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_ridership_16
# Out:
#       DATEMONTHINT                  STATION  RIDERS_PER_WEEKDAY
# 5786        201602            Union Station             29370.6
# 5742        201602  Gallery Place-Chinatown             25537.3
# 5695        201601            Union Station             25384.9
# 5733        201602           Farragut North             24597.0
# 5757        201602             Metro Center             24329.8
# 5651        201601  Gallery Place-Chinatown             22386.3
# 5642        201601           Farragut North             21596.2
# 5666        201601             Metro Center             21568.6
# 5734        201602            Farragut West             20917.1
# 5737        201602             Foggy Bottom             20120.8
# 5751        201602           L'Enfant Plaza             19342.6
# 5729        201602            Dupont Circle             18653.1
# 5643        201601            Farragut West             18297.8
# 5646        201601             Foggy Bottom             17861.0
# ...

# %%
#Bottom 50
bottom_50_ridership_16 = sort_riders_16.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_ridership_16
# Out:
#       DATEMONTHINT               STATION  RIDERS_PER_WEEKDAY
# 5619        201601    Arlington Cemetery               353.9
# 5710        201602    Arlington Cemetery               362.7
# 5687        201601           Spring Hill               929.6
# 5655        201601            Greensboro               960.4
# 5628        201601              Cheverly              1018.7
# 5778        201602           Spring Hill              1042.4
# 5746        201602            Greensboro              1079.1
# 5719        201602              Cheverly              1152.8
# 5636        201601              Deanwood              1244.2
# 5641        201601     Eisenhower Avenue              1305.2
# 5727        201602              Deanwood              1346.7
# 5661        201601              Landover              1468.6
# 5732        201602     Eisenhower Avenue              1485.8
# 5663        201601                McLean              1499.9
# ...

# %%
metro_stations_16 = sort_riders_16.groupby('STATION')
metro_stations_16.head(20)
# Out:
#       DATEMONTHINT                  STATION  RIDERS_PER_WEEKDAY
# 5786        201602            Union Station             29370.6
# 5742        201602  Gallery Place-Chinatown             25537.3
# 5695        201601            Union Station             25384.9
# 5733        201602           Farragut North             24597.0
# 5757        201602             Metro Center             24329.8
# 5651        201601  Gallery Place-Chinatown             22386.3
# 5642        201601           Farragut North             21596.2
# 5666        201601             Metro Center             21568.6
# 5734        201602            Farragut West             20917.1
# 5737        201602             Foggy Bottom             20120.8
# 5751        201602           L'Enfant Plaza             19342.6
# 5729        201602            Dupont Circle             18653.1
# 5643        201601            Farragut West             18297.8
# 5646        201601             Foggy Bottom             17861.0
# ...

# %% [markdown]
# Ridership by time period.

# %%
ridership_time = pd.read_excel('Resources/Avg-Weekday-Rail-Ridership-by-Month-by-Station-by-Period-2010-to-2016.xlsx')
ridership_time.head()
# Out:
#    DATEMONTHINT       STATION           PERIOD  RIDERS_PER_WEEKDAY
# 0        201009  Addison Road          AM Peak              2303.7
# 1        201009  Addison Road          Evening               211.0
# 2        201009  Addison Road  Late Night Peak                 5.1
# 3        201009  Addison Road           Midday               748.0
# 4        201009  Addison Road          PM Peak               399.6

# %% [markdown]
# Ridership by time period for 2014.

# %%
ridership_timeperiod_14 = ridership_time[(ridership_time.DATEMONTHINT > 201312) & (ridership_time.DATEMONTHINT <=201412)]
ridership_timeperiod_14.head()
# Out:
#        DATEMONTHINT       STATION           PERIOD  RIDERS_PER_WEEKDAY
# 17197        201401  Addison Road          AM Peak              1728.1
# 17198        201401  Addison Road          Evening               158.7
# 17199        201401  Addison Road  Late Night Peak                 4.8
# 17200        201401  Addison Road           Midday               648.4
# 17201        201401  Addison Road          PM Peak               305.8

# %%
timeperiod_14 = ridership_timeperiod_14.sort_values(['PERIOD','RIDERS_PER_WEEKDAY'], ascending=True)
timeperiod_14.head(20)
# Out:
#        DATEMONTHINT             STATION   PERIOD  RIDERS_PER_WEEKDAY
# 17859        201402              McLean  AM Peak                 0.0
# 19545        201406          Greensboro  AM Peak                 0.0
# 17567        201401       Tysons Corner  AM Peak                 1.0
# 17426        201401              McLean  AM Peak                 1.5
# 19700        201406         Spring Hill  AM Peak                 1.7
# 19582        201406              McLean  AM Peak                 2.3
# 19727        201406       Tysons Corner  AM Peak                 5.0
# 22079        201412  Arlington Cemetery  AM Peak                 9.1
# 17644        201402  Arlington Cemetery  AM Peak                 9.7
# 19784        201406              Wiehle  AM Peak                10.3
# 17212        201401  Arlington Cemetery  AM Peak                10.9
# 18076        201403  Arlington Cemetery  AM Peak                13.1
# 21624        201411  Arlington Cemetery  AM Peak                14.7
# ...

# %%
#top 50
top_50_ridership_timeperiod_14 = timeperiod_14.sort_values(['PERIOD','RIDERS_PER_WEEKDAY'], ascending=False).head(50)
top_50_ridership_timeperiod_14
# Out:
#        DATEMONTHINT                  STATION   PERIOD  RIDERS_PER_WEEKDAY
# 19599        201406             Metro Center  PM Peak             15929.7
# 20045        201407             Metro Center  PM Peak             15732.0
# 19484        201406           Farragut North  PM Peak             15699.4
# 21288        201410           Farragut North  PM Peak             15642.7
# 18736        201404             Metro Center  PM Peak             15637.3
# 20834        201409           Farragut North  PM Peak             15588.2
# 18625        201404           Farragut North  PM Peak             15371.2
# 21408        201410             Metro Center  PM Peak             15368.0
# 19165        201405             Metro Center  PM Peak             15315.6
# 19925        201407           Farragut North  PM Peak             15289.3
# 17763        201402           Farragut North  PM Peak             15138.7
# 20954        201409             Metro Center  PM Peak             15123.5
# ...

# %%
#Bottom 50
bottom_50_ridership_timeperiod_14 = timeperiod_14.sort_values(['PERIOD','RIDERS_PER_WEEKDAY'], ascending=True).head(50)
bottom_50_ridership_timeperiod_14
# Out:
#        DATEMONTHINT             STATION   PERIOD  RIDERS_PER_WEEKDAY
# 17859        201402              McLean  AM Peak                 0.0
# 19545        201406          Greensboro  AM Peak                 0.0
# 17567        201401       Tysons Corner  AM Peak                 1.0
# 17426        201401              McLean  AM Peak                 1.5
# 19700        201406         Spring Hill  AM Peak                 1.7
# 19582        201406              McLean  AM Peak                 2.3
# 19727        201406       Tysons Corner  AM Peak                 5.0
# 22079        201412  Arlington Cemetery  AM Peak                 9.1
# 17644        201402  Arlington Cemetery  AM Peak                 9.7
# 19784        201406              Wiehle  AM Peak                10.3
# 17212        201401  Arlington Cemetery  AM Peak                10.9
# 18076        201403  Arlington Cemetery  AM Peak                13.1
# 21624        201411  Arlington Cemetery  AM Peak                14.7
# ...

# %% [markdown]
# Ridership by time period for 2015.

# %%
ridership_timeperiod_15 = ridership_time[(ridership_time.DATEMONTHINT > 201412) & (ridership_time.DATEMONTHINT <=201512)]
ridership_timeperiod_15.head(20)
# Out:
#        DATEMONTHINT                 STATION           PERIOD  \
# 22518        201501            Addison Road          AM Peak
# 22519        201501            Addison Road          Evening
# 22520        201501            Addison Road  Late Night Peak
# 22521        201501            Addison Road           Midday
# 22522        201501            Addison Road          PM Peak
# 22523        201501               Anacostia          AM Peak
# 22524        201501               Anacostia          Evening
# 22525        201501               Anacostia  Late Night Peak
# 22526        201501               Anacostia           Midday
# 22527        201501               Anacostia          PM Peak
# 22528        201501  Archives-Navy Memorial          AM Peak
# 22529        201501  Archives-Navy Memorial          Evening
# 22530        201501  Archives-Navy Memorial  Late Night Peak
# 22531        201501  Archives-Navy Memorial           Midday
# ...

# %%
timeperiod_15 = ridership_timeperiod_15.sort_values(['PERIOD','RIDERS_PER_WEEKDAY'], ascending=False)
timeperiod_15.head(20)
# Out:
#        DATEMONTHINT         STATION   PERIOD  RIDERS_PER_WEEKDAY
# 25044        201506    Metro Center  PM Peak             15680.0
# 24134        201504    Metro Center  PM Peak             15391.9
# 26743        201510  Farragut North  PM Peak             15388.5
# 24924        201506  Farragut North  PM Peak             15365.0
# 24014        201504  Farragut North  PM Peak             15351.6
# 25499        201507    Metro Center  PM Peak             15350.2
# 24469        201505  Farragut North  PM Peak             15128.8
# 25379        201507  Farragut North  PM Peak             14740.5
# 27198        201511  Farragut North  PM Peak             14714.6
# 24589        201505    Metro Center  PM Peak             14695.4
# 23560        201503  Farragut North  PM Peak             14690.9
# 23106        201502  Farragut North  PM Peak             14662.5
# 22652        201501  Farragut North  PM Peak             14647.7
# ...

# %%
#Top 50
top_50_ridership_timeperiod_15 = timeperiod_15.sort_values(['PERIOD','RIDERS_PER_WEEKDAY'], ascending=False).head(50)
top_50_ridership_timeperiod_15
# Out:
#        DATEMONTHINT                  STATION   PERIOD  RIDERS_PER_WEEKDAY
# 25044        201506             Metro Center  PM Peak             15680.0
# 24134        201504             Metro Center  PM Peak             15391.9
# 26743        201510           Farragut North  PM Peak             15388.5
# 24924        201506           Farragut North  PM Peak             15365.0
# 24014        201504           Farragut North  PM Peak             15351.6
# 25499        201507             Metro Center  PM Peak             15350.2
# 24469        201505           Farragut North  PM Peak             15128.8
# 25379        201507           Farragut North  PM Peak             14740.5
# 27198        201511           Farragut North  PM Peak             14714.6
# 24589        201505             Metro Center  PM Peak             14695.4
# 23560        201503           Farragut North  PM Peak             14690.9
# 23106        201502           Farragut North  PM Peak             14662.5
# ...

# %%
#Bottom 50
bottom_50_ridership_timeperiod_15 = timeperiod_15.sort_values(['PERIOD','RIDERS_PER_WEEKDAY'], ascending=True).head(50)
bottom_50_ridership_timeperiod_15
# Out:
#        DATEMONTHINT                 STATION   PERIOD  RIDERS_PER_WEEKDAY
# 22988        201502      Arlington Cemetery  AM Peak                 9.2
# 22533        201501      Arlington Cemetery  AM Peak                11.4
# 27534        201512      Arlington Cemetery  AM Peak                14.0
# 27079        201511      Arlington Cemetery  AM Peak                15.1
# 23442        201503      Arlington Cemetery  AM Peak                15.9
# 26624        201510      Arlington Cemetery  AM Peak                16.3
# 26170        201509      Arlington Cemetery  AM Peak                18.4
# 23896        201504      Arlington Cemetery  AM Peak                18.9
# 24350        201505      Arlington Cemetery  AM Peak                21.1
# 24805        201506      Arlington Cemetery  AM Peak                21.1
# 25715        201508      Arlington Cemetery  AM Peak                22.8
# 25260        201507      Arlington Cemetery  AM Peak                23.6
# ...

# %% [markdown]
# Ridership by time period for 2016.

# %%
ridership_timeperiod_16 = ridership_time[(ridership_time.DATEMONTHINT > 201512) & (ridership_time.DATEMONTHINT <=201612)]
ridership_timeperiod_16.head()
# Out:
#        DATEMONTHINT       STATION           PERIOD  RIDERS_PER_WEEKDAY
# 27974        201601  Addison Road          AM Peak              1632.9
# 27975        201601  Addison Road          Evening               129.3
# 27976        201601  Addison Road  Late Night Peak                 2.1
# 27977        201601  Addison Road           Midday               594.1
# 27978        201601  Addison Road          PM Peak               259.6

# %%
timeperiod_16 = ridership_timeperiod_16.sort_values(['PERIOD','RIDERS_PER_WEEKDAY'], ascending=False)
timeperiod_16.head(20)
# Out:
#        DATEMONTHINT                  STATION   PERIOD  RIDERS_PER_WEEKDAY
# 28563        201602           Farragut North  PM Peak             16009.6
# 28683        201602             Metro Center  PM Peak             14064.8
# 28108        201601           Farragut North  PM Peak             13935.6
# 28568        201602            Farragut West  PM Peak             13151.3
# 28653        201602           L'Enfant Plaza  PM Peak             12631.9
# 28228        201601             Metro Center  PM Peak             12442.5
# 28828        201602            Union Station  PM Peak             11604.6
# 28608        201602  Gallery Place-Chinatown  PM Peak             11490.0
# 28113        201601            Farragut West  PM Peak             11385.3
# 28198        201601           L'Enfant Plaza  PM Peak             10672.4
# 28583        201602             Foggy Bottom  PM Peak             10406.0
# 28153        201601  Gallery Place-Chinatown  PM Peak             10354.7
# ...

# %%
#Top 50
top_50_ridership_timeperiod_16 = timeperiod_16.sort_values(['PERIOD','RIDERS_PER_WEEKDAY'], ascending=False).head(50)
top_50_ridership_timeperiod_16
# Out:
#        DATEMONTHINT                  STATION   PERIOD  RIDERS_PER_WEEKDAY
# 28563        201602           Farragut North  PM Peak             16009.6
# 28683        201602             Metro Center  PM Peak             14064.8
# 28108        201601           Farragut North  PM Peak             13935.6
# 28568        201602            Farragut West  PM Peak             13151.3
# 28653        201602           L'Enfant Plaza  PM Peak             12631.9
# 28228        201601             Metro Center  PM Peak             12442.5
# 28828        201602            Union Station  PM Peak             11604.6
# 28608        201602  Gallery Place-Chinatown  PM Peak             11490.0
# 28113        201601            Farragut West  PM Peak             11385.3
# 28198        201601           L'Enfant Plaza  PM Peak             10672.4
# 28583        201602             Foggy Bottom  PM Peak             10406.0
# 28153        201601  Gallery Place-Chinatown  PM Peak             10354.7
# ...

# %%
#Bottom 50
bottom_50_ridership_timeperiod_16 = timeperiod_16.sort_values(['PERIOD','RIDERS_PER_WEEKDAY'], ascending=True).head(50)
bottom_50_ridership_timeperiod_16
# Out:
#        DATEMONTHINT                             STATION   PERIOD  \
# 28444        201602                  Arlington Cemetery  AM Peak
# 27989        201601                  Arlington Cemetery  AM Peak
# 28119        201601                    Federal Triangle  AM Peak
# 28574        201602                    Federal Triangle  AM Peak
# 28319        201601                         Smithsonian  AM Peak
# 28774        201602                         Smithsonian  AM Peak
# 28169        201601                          Greensboro  AM Peak
# 28624        201602                          Greensboro  AM Peak
# 27984        201601              Archives-Navy Memorial  AM Peak
# 28329        201601                         Spring Hill  AM Peak
# 28439        201602              Archives-Navy Memorial  AM Peak
# 28784        201602                         Spring Hill  AM Peak
# 28114        201601                   Federal Center SW  AM Peak
# ...

# %% [markdown]
# Average ridership and total ridership per Metrorail station for 2014.

# %%
ridership_average_14 = ridership_14.groupby('STATION')[['RIDERS_PER_WEEKDAY']].mean()
ridership_average_14
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Addison Road                               3252.808333
# Anacostia                                  7157.666667
# Archives-Navy Memorial                     8747.475000
# Arlington Cemetery                         1305.541667
# Ballston                                  11416.391667
# Benning Road                               3058.708333
# Bethesda                                  10450.141667
# Braddock Road                              4496.816667
# Branch Avenue                              6199.683333
# Brookland                                  6614.500000
# Capitol Heights                            2010.541667
# Capitol South                              7752.091667
# Cheverly                                   1414.891667
# Clarendon                                  4593.891667
# Cleveland Park                             4338.250000
# College Park-U of MD                       4443.341667
# ...

# %%
ridership_total_14 = ridership_14.groupby('STATION')[['RIDERS_PER_WEEKDAY']].sum()
ridership_total_14.head(50)
# Out:
#                          RIDERS_PER_WEEKDAY
# STATION
# Addison Road                        39033.7
# Anacostia                           85892.0
# Archives-Navy Memorial             104969.7
# Arlington Cemetery                  15666.5
# Ballston                           136996.7
# Benning Road                        36704.5
# Bethesda                           125401.7
# Braddock Road                       53961.8
# Branch Avenue                       74396.2
# Brookland                           79374.0
# Capitol Heights                     24126.5
# Capitol South                       93025.1
# Cheverly                            16978.7
# Clarendon                           55126.7
# Cleveland Park                      52059.0
# College Park-U of MD                53320.1
# Columbia Heights                   147297.2
# Congress Heights                    31787.7
# Court House                         90117.4
# Crystal City                       140709.0
# ...

# %%
top_50_ridership_average_14 = ridership_average_14.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_ridership_average_14
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Union Station                             31020.375000
# Metro Center                              26758.533333
# Gallery Place-Chinatown                   25316.091667
# Farragut North                            24152.883333
# Farragut West                             21904.050000
# Foggy Bottom                              20240.808333
# Dupont Circle                             20098.325000
# L'Enfant Plaza                            19230.858333
# McPherson Square                          15587.266667
# Pentagon                                  15200.491667
# Rosslyn                                   15023.991667
# Pentagon City                             14669.875000
# Shady Grove                               12549.133333
# Silver Spring                             12427.208333
# Columbia Heights                          12274.766667
# Vienna                                    11854.641667
# ...

# %%
top_50_ridership_total_14 = ridership_total_14.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_ridership_total_14
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Union Station                                 372244.5
# Metro Center                                  321102.4
# Gallery Place-Chinatown                       303793.1
# Farragut North                                289834.6
# Farragut West                                 262848.6
# Foggy Bottom                                  242889.7
# Dupont Circle                                 241179.9
# L'Enfant Plaza                                230770.3
# McPherson Square                              187047.2
# Pentagon                                      182405.9
# Rosslyn                                       180287.9
# Pentagon City                                 176038.5
# Shady Grove                                   150589.6
# Silver Spring                                 149126.5
# Columbia Heights                              147297.2
# Vienna                                        142255.7
# ...

# %%
bottom_50_ridership_average_14 = ridership_average_14.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_ridership_average_14
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Greensboro                                  538.655556
# McLean                                      760.830000
# Spring Hill                                 958.957143
# Arlington Cemetery                         1305.541667
# Cheverly                                   1414.891667
# Deanwood                                   1590.233333
# Eisenhower Avenue                          1778.741667
# Tysons Corner                              1945.287500
# Landover                                   1979.233333
# Capitol Heights                            2010.541667
# Morgan Blvd.                               2133.125000
# Forest Glen                                2297.066667
# Congress Heights                           2648.975000
# Minnesota Avenue                           2860.100000
# Naylor Road                                2877.975000
# Stadium-Armory                             2894.075000
# ...

# %%
bottom_50_ridership_total_14 = ridership_total_14.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_ridership_total_14
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Greensboro                                      4847.9
# Spring Hill                                     6712.7
# McLean                                          7608.3
# Tysons Corner                                  15562.3
# Arlington Cemetery                             15666.5
# Cheverly                                       16978.7
# Deanwood                                       19082.8
# Eisenhower Avenue                              21344.9
# Landover                                       23750.8
# Capitol Heights                                24126.5
# Morgan Blvd.                                   25597.5
# Forest Glen                                    27564.8
# Congress Heights                               31787.7
# Minnesota Avenue                               34321.2
# Naylor Road                                    34535.7
# Stadium-Armory                                 34728.9
# ...

# %% [markdown]
# Average and total ridership by time period for 2014.

# %%
ridership_timeperiod_average_14 = ridership_timeperiod_14.groupby(['STATION','PERIOD'])[['RIDERS_PER_WEEKDAY']].mean()
ridership_timeperiod_average_14
# Out:
#                                         RIDERS_PER_WEEKDAY
# STATION                PERIOD
# Addison Road           AM Peak                 1967.800000
#                        Evening                  192.266667
#                        Late Night Peak            5.583333
#                        Midday                   746.625000
#                        PM Peak                  347.391667
# Anacostia              AM Peak                 2893.400000
#                        Evening                  526.525000
#                        Late Night Peak           15.675000
#                        Midday                  1948.625000
#                        PM Peak                 1773.458333
# Archives-Navy Memorial AM Peak                  370.591667
#                        Evening                 1277.691667
#                        Late Night Peak           26.241667
#                        Midday                  1514.200000
# ...

# %%
ridership_timeperiod_total_14 = ridership_timeperiod_14.groupby(['STATION','PERIOD'])[['RIDERS_PER_WEEKDAY']].sum()
ridership_timeperiod_total_14
# Out:
#                                         RIDERS_PER_WEEKDAY
# STATION                PERIOD
# Addison Road           AM Peak                     23613.6
#                        Evening                      2307.2
#                        Late Night Peak                67.0
#                        Midday                       8959.5
#                        PM Peak                      4168.7
# Anacostia              AM Peak                     34720.8
#                        Evening                      6318.3
#                        Late Night Peak               188.1
#                        Midday                      23383.5
#                        PM Peak                     21281.5
# Archives-Navy Memorial AM Peak                      4447.1
#                        Evening                     15332.3
#                        Late Night Peak               314.9
#                        Midday                      18170.4
# ...

# %%
top_50_ridership_timeperiod_average_14 = ridership_timeperiod_average_14.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_ridership_timeperiod_average_14
# Out:
#                                  RIDERS_PER_WEEKDAY
# STATION                 PERIOD
# Farragut North          PM Peak        14947.533333
# Metro Center            PM Peak        14780.833333
# Farragut West           PM Peak        13332.975000
# Union Station           PM Peak        12054.116667
# L'Enfant Plaza          PM Peak        12045.200000
# Gallery Place-Chinatown PM Peak        11361.125000
# Foggy Bottom            PM Peak         9620.041667
# Union Station           AM Peak         9357.608333
# McPherson Square        PM Peak         9172.000000
# Shady Grove             AM Peak         8552.416667
# Vienna                  AM Peak         8270.108333
# Dupont Circle           PM Peak         7862.083333
# Gallery Place-Chinatown Evening         7785.216667
# Smithsonian             PM Peak         6966.125000
# Pentagon                PM Peak         6098.441667
# Rosslyn                 PM Peak         6086.575000
# ...

# %%
top_50_ridership_total_14 = ridership_timeperiod_total_14.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_ridership_total_14
# Out:
#                                  RIDERS_PER_WEEKDAY
# STATION                 PERIOD
# Farragut North          PM Peak            179370.4
# Metro Center            PM Peak            177370.0
# Farragut West           PM Peak            159995.7
# Union Station           PM Peak            144649.4
# L'Enfant Plaza          PM Peak            144542.4
# Gallery Place-Chinatown PM Peak            136333.5
# Foggy Bottom            PM Peak            115440.5
# Union Station           AM Peak            112291.3
# McPherson Square        PM Peak            110064.0
# Shady Grove             AM Peak            102629.0
# Vienna                  AM Peak             99241.3
# Dupont Circle           PM Peak             94345.0
# Gallery Place-Chinatown Evening             93422.6
# Smithsonian             PM Peak             83593.5
# Pentagon                PM Peak             73181.3
# Rosslyn                 PM Peak             73038.9
# ...

# %%
bottom_50_ridership_timeperiod_average_14 = ridership_timeperiod_average_14.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_ridership_timeperiod_average_14
# Out:
#                                        RIDERS_PER_WEEKDAY
# STATION               PERIOD
# Arlington Cemetery    Late Night Peak            0.750000
# Greensboro            Late Night Peak            1.450000
# Cheverly              Late Night Peak            1.716667
# McLean                Late Night Peak            1.750000
# Spring Hill           Late Night Peak            2.000000
# Forest Glen           Late Night Peak            2.591667
# Federal Center SW     Late Night Peak            2.766667
# Van Dorn Street       Late Night Peak            3.433333
# Branch Avenue         Late Night Peak            3.916667
# Landover              Late Night Peak            3.991667
# Pentagon              Late Night Peak            4.000000
# Deanwood              Late Night Peak            4.166667
# Franconia-Springfield Late Night Peak            4.383333
# Capitol Heights       Late Night Peak            4.766667
# Grosvenor             Late Night Peak            4.908333
# ...

# %%
bottom_50_ridership_total_14 = ridership_timeperiod_total_14.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_ridership_total_14
# Out:
#                                        RIDERS_PER_WEEKDAY
# STATION               PERIOD
# Arlington Cemetery    Late Night Peak                 3.0
# Greensboro            Late Night Peak                 8.7
# McLean                Late Night Peak                10.5
# Spring Hill           Late Night Peak                12.0
# Cheverly              Late Night Peak                20.6
# Wiehle                Late Night Peak                29.5
# Forest Glen           Late Night Peak                31.1
# Federal Center SW     Late Night Peak                33.2
# Van Dorn Street       Late Night Peak                41.2
# Branch Avenue         Late Night Peak                47.0
# Landover              Late Night Peak                47.9
# Pentagon              Late Night Peak                48.0
# Deanwood              Late Night Peak                50.0
# Franconia-Springfield Late Night Peak                52.6
# Tysons Corner         Late Night Peak                54.9
# ...

# %%
average_by_timeperiod_14 = ridership_timeperiod_14.groupby('PERIOD')[['RIDERS_PER_WEEKDAY']].mean()
average_by_timeperiod_14
# Out:
#                  RIDERS_PER_WEEKDAY
# PERIOD
# AM Peak                 2541.874019
# Evening                  944.099906
# Late Night Peak           30.885674
# Midday                  1511.148041
# PM Peak                 2768.547274

# %%
total_by_timeperiod_14 = ridership_timeperiod_14.groupby('PERIOD')[['RIDERS_PER_WEEKDAY']].sum()
total_by_timeperiod_14
# Out:
#                  RIDERS_PER_WEEKDAY
# PERIOD
# AM Peak                   2719805.2
# Evening                   1001690.0
# Late Night Peak             32553.5
# Midday                    1619950.7
# PM Peak                   2945734.3

# %% [markdown]
# Average and total ridership for 2015.

# %%
ridership_average_15 = ridership_15.groupby('STATION')[['RIDERS_PER_WEEKDAY']].mean()
ridership_average_15
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Addison Road                               3151.558333
# Anacostia                                  6912.066667
# Archives-Navy Memorial                     8630.691667
# Arlington Cemetery                         1359.308333
# Ballston                                  11074.183333
# Benning Road                               2902.675000
# Bethesda                                  10044.441667
# Braddock Road                              4544.900000
# Branch Avenue                              5753.108333
# Brookland                                  6471.341667
# Capitol Heights                            1943.233333
# Capitol South                              7450.025000
# Cheverly                                   1255.891667
# Clarendon                                  4594.350000
# Cleveland Park                             4088.808333
# College Park-U of MD                       4245.858333
# ...

# %%
ridership_total_15 = ridership_15.groupby('STATION')[['RIDERS_PER_WEEKDAY']].sum()
ridership_total_15
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Addison Road                                   37818.7
# Anacostia                                      82944.8
# Archives-Navy Memorial                        103568.3
# Arlington Cemetery                             16311.7
# Ballston                                      132890.2
# Benning Road                                   34832.1
# Bethesda                                      120533.3
# Braddock Road                                  54538.8
# Branch Avenue                                  69037.3
# Brookland                                      77656.1
# Capitol Heights                                23318.8
# Capitol South                                  89400.3
# Cheverly                                       15070.7
# Clarendon                                      55132.2
# Cleveland Park                                 49065.7
# College Park-U of MD                           50950.3
# ...

# %%
top_50_ridership_total_15 = ridership_total_15.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_ridership_total_15
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Union Station                                 357685.8
# Metro Center                                  307914.8
# Gallery Place-Chinatown                       298690.0
# Farragut North                                282793.2
# Farragut West                                 253829.4
# Foggy Bottom                                  248613.5
# L'Enfant Plaza                                235626.8
# Dupont Circle                                 230987.0
# McPherson Square                              177863.7
# Pentagon                                      173649.2
# Rosslyn                                       171038.1
# Pentagon City                                 160266.9
# Silver Spring                                 148245.8
# Shady Grove                                   142012.3
# Columbia Heights                              141762.4
# Crystal City                                  139544.4
# ...

# %%
top_50_ridership_average_15 = ridership_average_15.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_ridership_average_15
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Union Station                             29807.150000
# Metro Center                              25659.566667
# Gallery Place-Chinatown                   24890.833333
# Farragut North                            23566.100000
# Farragut West                             21152.450000
# Foggy Bottom                              20717.791667
# L'Enfant Plaza                            19635.566667
# Dupont Circle                             19248.916667
# McPherson Square                          14821.975000
# Pentagon                                  14470.766667
# Rosslyn                                   14253.175000
# Pentagon City                             13355.575000
# Silver Spring                             12353.816667
# Shady Grove                               11834.358333
# Columbia Heights                          11813.533333
# Crystal City                              11628.700000
# ...

# %%
bottom_50_ridership_total_15 = ridership_total_15.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_ridership_total_15
# Out:
#                          RIDERS_PER_WEEKDAY
# STATION
# Greensboro                          12503.1
# Spring Hill                         14978.9
# Cheverly                            15070.7
# Arlington Cemetery                  16311.7
# Deanwood                            17487.0
# McLean                              19010.5
# Eisenhower Avenue                   19425.5
# Landover                            21495.6
# Capitol Heights                     23318.8
# Morgan Blvd.                        24442.0
# Forest Glen                         27295.8
# Congress Heights                    29853.7
# Minnesota Avenue                    30540.3
# Stadium-Armory                      31177.2
# Naylor Road                         32031.0
# West Falls Church                   34310.8
# Benning Road                        34832.1
# Tysons Corner                       36715.2
# Van Dorn Street                     37469.0
# Addison Road                        37818.7
# ...

# %%
bottom_50_ridership_average_15 = ridership_average_15.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_ridership_average_15
# Out:
#                          RIDERS_PER_WEEKDAY
# STATION
# Greensboro                      1041.925000
# Spring Hill                     1248.241667
# Cheverly                        1255.891667
# Arlington Cemetery              1359.308333
# Deanwood                        1457.250000
# McLean                          1584.208333
# Eisenhower Avenue               1618.791667
# Landover                        1791.300000
# Capitol Heights                 1943.233333
# Morgan Blvd.                    2036.833333
# Forest Glen                     2274.650000
# Congress Heights                2487.808333
# Minnesota Avenue                2545.025000
# Stadium-Armory                  2598.100000
# Naylor Road                     2669.250000
# West Falls Church               2859.233333
# Benning Road                    2902.675000
# Tysons Corner                   3059.600000
# Van Dorn Street                 3122.416667
# Addison Road                    3151.558333
# ...

# %% [markdown]
# Average and total ridership by time period for 2015.

# %%
ridership_timeperiod_average_15 = ridership_timeperiod_15.groupby(['STATION','PERIOD'])[['RIDERS_PER_WEEKDAY']].mean()
ridership_timeperiod_average_15
# Out:
#                                         RIDERS_PER_WEEKDAY
# STATION                PERIOD
# Addison Road           AM Peak                 1918.866667
#                        Evening                  178.858333
#                        Late Night Peak            4.408333
#                        Midday                   716.950000
#                        PM Peak                  332.491667
# Anacostia              AM Peak                 2841.316667
#                        Evening                  478.716667
#                        Late Night Peak           14.225000
#                        Midday                  1910.658333
#                        PM Peak                 1667.175000
# Archives-Navy Memorial AM Peak                  370.908333
#                        Evening                 1251.500000
#                        Late Night Peak           28.175000
#                        Midday                  1476.183333
# ...

# %%
ridership_timeperiod_total_15 = ridership_timeperiod_15.groupby(['STATION','PERIOD'])[['RIDERS_PER_WEEKDAY']].sum()
ridership_timeperiod_total_15
# Out:
#                                         RIDERS_PER_WEEKDAY
# STATION                PERIOD
# Addison Road           AM Peak                     23026.4
#                        Evening                      2146.3
#                        Late Night Peak                52.9
#                        Midday                       8603.4
#                        PM Peak                      3989.9
# Anacostia              AM Peak                     34095.8
#                        Evening                      5744.6
#                        Late Night Peak               170.7
#                        Midday                      22927.9
#                        PM Peak                     20006.1
# Archives-Navy Memorial AM Peak                      4450.9
#                        Evening                     15018.0
#                        Late Night Peak               338.1
#                        Midday                      17714.2
# ...

# %%
top_50_ridership_timeperiod_average_15 = ridership_timeperiod_average_15.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_ridership_timeperiod_average_15
# Out:
#                                  RIDERS_PER_WEEKDAY
# STATION                 PERIOD
# Farragut North          PM Peak        14753.625000
# Metro Center            PM Peak        14280.700000
# Farragut West           PM Peak        12928.525000
# L'Enfant Plaza          PM Peak        12453.641667
# Union Station           PM Peak        11606.150000
# Gallery Place-Chinatown PM Peak        11383.591667
# Foggy Bottom            PM Peak        10102.008333
# Union Station           AM Peak         9142.666667
# McPherson Square        PM Peak         8677.966667
# Shady Grove             AM Peak         7988.991667
# Dupont Circle           PM Peak         7676.775000
# Gallery Place-Chinatown Evening         7562.400000
# Vienna                  AM Peak         7238.500000
# Smithsonian             PM Peak         6608.875000
# Silver Spring           AM Peak         5812.983333
# Pentagon                PM Peak         5788.908333
# ...

# %%
top_50_ridership_timeperiod_total_15 = ridership_timeperiod_total_15.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_ridership_timeperiod_total_15
# Out:
#                                  RIDERS_PER_WEEKDAY
# STATION                 PERIOD
# Farragut North          PM Peak            177043.5
# Metro Center            PM Peak            171368.4
# Farragut West           PM Peak            155142.3
# L'Enfant Plaza          PM Peak            149443.7
# Union Station           PM Peak            139273.8
# Gallery Place-Chinatown PM Peak            136603.1
# Foggy Bottom            PM Peak            121224.1
# Union Station           AM Peak            109712.0
# McPherson Square        PM Peak            104135.6
# Shady Grove             AM Peak             95867.9
# Dupont Circle           PM Peak             92121.3
# Gallery Place-Chinatown Evening             90748.8
# Vienna                  AM Peak             86862.0
# Smithsonian             PM Peak             79306.5
# Silver Spring           AM Peak             69755.8
# Pentagon                PM Peak             69466.9
# ...

# %%
bottom_50_ridership_timeperiod_average_15 = ridership_timeperiod_average_15.sort_values('RIDERS_PER_WEEKDAY',ascending=True).head(50)
bottom_50_ridership_timeperiod_average_15
# Out:
#                                        RIDERS_PER_WEEKDAY
# STATION               PERIOD
# Arlington Cemetery    Late Night Peak            0.937500
# Greensboro            Late Night Peak            1.000000
# McLean                Late Night Peak            1.291667
# Cheverly              Late Night Peak            1.450000
# Spring Hill           Late Night Peak            1.800000
# Forest Glen           Late Night Peak            1.816667
# Federal Center SW     Late Night Peak            2.608333
# West Falls Church     Late Night Peak            2.666667
# Van Dorn Street       Late Night Peak            2.783333
# Deanwood              Late Night Peak            2.975000
# Landover              Late Night Peak            3.016667
# Branch Avenue         Late Night Peak            3.166667
# Capitol Heights       Late Night Peak            3.600000
# Grosvenor             Late Night Peak            3.891667
# Pentagon              Late Night Peak            3.925000
# ...

# %%
bottom_50_ridership_timeperiod_total_15 = ridership_timeperiod_total_15.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_ridership_timeperiod_total_15
# Out:
#                                        RIDERS_PER_WEEKDAY
# STATION               PERIOD
# Arlington Cemetery    Late Night Peak                 7.5
# Greensboro            Late Night Peak                12.0
# McLean                Late Night Peak                15.5
# Cheverly              Late Night Peak                17.4
# Spring Hill           Late Night Peak                21.6
# Forest Glen           Late Night Peak                21.8
# Federal Center SW     Late Night Peak                31.3
# West Falls Church     Late Night Peak                32.0
# Van Dorn Street       Late Night Peak                33.4
# Deanwood              Late Night Peak                35.7
# Landover              Late Night Peak                36.2
# Branch Avenue         Late Night Peak                38.0
# Capitol Heights       Late Night Peak                43.2
# Grosvenor             Late Night Peak                46.7
# Pentagon              Late Night Peak                47.1
# ...

# %%
average_by_timeperiod_15 = ridership_timeperiod_15.groupby('PERIOD')[['RIDERS_PER_WEEKDAY']].mean()
average_by_timeperiod_15
# Out:
#                  RIDERS_PER_WEEKDAY
# PERIOD
# AM Peak                 2432.898168
# Evening                  865.308333
# Late Night Peak           24.496599
# Midday                  1435.479579
# PM Peak                 2649.875092

# %%
total_by_timeperiod_15 = ridership_timeperiod_15.groupby('PERIOD')[['RIDERS_PER_WEEKDAY']].sum()
total_by_timeperiod_15
# Out:
#                  RIDERS_PER_WEEKDAY
# PERIOD
# AM Peak                   2656724.8
# Evening                    944916.7
# Late Night Peak             26652.3
# Midday                    1567543.7
# PM Peak                   2893663.6

# %% [markdown]
# Average and total ridership for 2016.

# %%
ridership_average_16 = ridership_16.groupby('STATION')[['RIDERS_PER_WEEKDAY']].mean()
ridership_average_16
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Addison Road                                   2751.55
# Anacostia                                      6379.45
# Archives-Navy Memorial                         7405.80
# Arlington Cemetery                              358.30
# Ballston                                      10240.90
# Benning Road                                   2634.30
# Bethesda                                       9436.95
# Braddock Road                                  4420.60
# Branch Avenue                                  5082.75
# Brookland                                      6012.15
# Capitol Heights                                1793.40
# Capitol South                                  6372.55
# Cheverly                                       1085.75
# Clarendon                                      4253.75
# Cleveland Park                                 3827.75
# College Park-U of MD                           3592.25
# ...

# %%
ridership_total_16 = ridership_16.groupby('STATION')[['RIDERS_PER_WEEKDAY']].sum()
ridership_total_16
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Addison Road                                    5503.1
# Anacostia                                      12758.9
# Archives-Navy Memorial                         14811.6
# Arlington Cemetery                               716.6
# Ballston                                       20481.8
# Benning Road                                    5268.6
# Bethesda                                       18873.9
# Braddock Road                                   8841.2
# Branch Avenue                                  10165.5
# Brookland                                      12024.3
# Capitol Heights                                 3586.8
# Capitol South                                  12745.1
# Cheverly                                        2171.5
# Clarendon                                       8507.5
# Cleveland Park                                  7655.5
# College Park-U of MD                            7184.5
# ...

# %%
top_50_ridership_average_16 = ridership_average_16.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_ridership_average_16
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Union Station                                 27377.75
# Gallery Place-Chinatown                       23961.80
# Farragut North                                23096.60
# Metro Center                                  22949.20
# Farragut West                                 19607.45
# Foggy Bottom                                  18990.90
# L'Enfant Plaza                                17925.50
# Dupont Circle                                 17625.10
# Pentagon                                      13498.25
# McPherson Square                              13445.55
# Rosslyn                                       12819.30
# Pentagon City                                 11778.85
# Silver Spring                                 11490.75
# Columbia Heights                              11457.75
# Shady Grove                                   10903.30
# Crystal City                                  10442.05
# ...

# %%
top_50_ridership_total_16 = ridership_total_16.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_ridership_total_16
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Union Station                                  54755.5
# Gallery Place-Chinatown                        47923.6
# Farragut North                                 46193.2
# Metro Center                                   45898.4
# Farragut West                                  39214.9
# Foggy Bottom                                   37981.8
# L'Enfant Plaza                                 35851.0
# Dupont Circle                                  35250.2
# Pentagon                                       26996.5
# McPherson Square                               26891.1
# Rosslyn                                        25638.6
# Pentagon City                                  23557.7
# Silver Spring                                  22981.5
# Columbia Heights                               22915.5
# Shady Grove                                    21806.6
# Crystal City                                   20884.1
# ...

# %%
bottom_50_ridership_average_16 = ridership_average_16.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_ridership_average_16
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Arlington Cemetery                              358.30
# Spring Hill                                     986.00
# Greensboro                                     1019.75
# Cheverly                                       1085.75
# Deanwood                                       1295.45
# Eisenhower Avenue                              1395.50
# McLean                                         1531.05
# Landover                                       1567.90
# Morgan Blvd.                                   1729.85
# Capitol Heights                                1793.40
# Forest Glen                                    2119.85
# Minnesota Avenue                               2227.85
# Congress Heights                               2292.05
# Naylor Road                                    2329.65
# Stadium-Armory                                 2330.00
# West Falls Church                              2512.65
# ...

# %% [markdown]
# Average and total ridership by time period for 2016.

# %%
ridership_timeperiod_average_16 = ridership_timeperiod_16.groupby(['STATION','PERIOD'])[['RIDERS_PER_WEEKDAY']].mean()
ridership_timeperiod_average_16
# Out:
#                                         RIDERS_PER_WEEKDAY
# STATION                PERIOD
# Addison Road           AM Peak                     1738.95
#                        Evening                      144.60
#                        Late Night Peak                2.55
#                        Midday                       619.80
#                        PM Peak                      288.80
# Anacostia              AM Peak                     2673.35
#                        Evening                      415.95
#                        Late Night Peak               13.75
#                        Midday                      1665.35
#                        PM Peak                     1611.50
# Archives-Navy Memorial AM Peak                      337.85
#                        Evening                      968.20
#                        Late Night Peak               19.60
#                        Midday                      1185.60
# ...

# %%
ridership_timeperiod_total_16 = ridership_timeperiod_16.groupby(['STATION','PERIOD'])[['RIDERS_PER_WEEKDAY']].sum()
ridership_timeperiod_total_16
# Out:
#                                         RIDERS_PER_WEEKDAY
# STATION                PERIOD
# Addison Road           AM Peak                      3477.9
#                        Evening                       289.2
#                        Late Night Peak                 5.1
#                        Midday                       1239.6
#                        PM Peak                       577.6
# Anacostia              AM Peak                      5346.7
#                        Evening                       831.9
#                        Late Night Peak                27.5
#                        Midday                       3330.7
#                        PM Peak                      3223.0
# Archives-Navy Memorial AM Peak                       675.7
#                        Evening                      1936.4
#                        Late Night Peak                39.2
#                        Midday                       2371.2
# ...

# %%
top_50_ridership_timeperiod_average_16 = ridership_timeperiod_average_16.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_ridership_timeperiod_average_16
# Out:
#                                  RIDERS_PER_WEEKDAY
# STATION                 PERIOD
# Farragut North          PM Peak            14972.60
# Metro Center            PM Peak            13253.65
# Farragut West           PM Peak            12268.30
# L'Enfant Plaza          PM Peak            11652.15
# Gallery Place-Chinatown PM Peak            10922.35
# Union Station           PM Peak            10760.70
# Foggy Bottom            PM Peak            10108.95
# Union Station           AM Peak             8937.15
# McPherson Square        PM Peak             8086.35
# Shady Grove             AM Peak             7705.60
# Gallery Place-Chinatown Evening             7702.40
# Dupont Circle           PM Peak             7425.80
# Vienna                  AM Peak             6573.05
# Silver Spring           AM Peak             5752.85
# Pentagon                PM Peak             5700.10
# Rosslyn                 PM Peak             5411.15
# ...

# %%
top_50_ridership_timeperiod_total_16 = ridership_timeperiod_total_16.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_ridership_timeperiod_total_16
# Out:
#                                  RIDERS_PER_WEEKDAY
# STATION                 PERIOD
# Farragut North          PM Peak             29945.2
# Metro Center            PM Peak             26507.3
# Farragut West           PM Peak             24536.6
# L'Enfant Plaza          PM Peak             23304.3
# Gallery Place-Chinatown PM Peak             21844.7
# Union Station           PM Peak             21521.4
# Foggy Bottom            PM Peak             20217.9
# Union Station           AM Peak             17874.3
# McPherson Square        PM Peak             16172.7
# Shady Grove             AM Peak             15411.2
# Gallery Place-Chinatown Evening             15404.8
# Dupont Circle           PM Peak             14851.6
# Vienna                  AM Peak             13146.1
# Silver Spring           AM Peak             11505.7
# Pentagon                PM Peak             11400.2
# Rosslyn                 PM Peak             10822.3
# ...

# %%
bottom_50_ridership_timeperiod_total_16 = ridership_total_16.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_ridership_timeperiod_total_16
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Arlington Cemetery                               716.6
# Spring Hill                                     1972.0
# Greensboro                                      2039.5
# Cheverly                                        2171.5
# Deanwood                                        2590.9
# Eisenhower Avenue                               2791.0
# McLean                                          3062.1
# Landover                                        3135.8
# Morgan Blvd.                                    3459.7
# Capitol Heights                                 3586.8
# Forest Glen                                     4239.7
# Minnesota Avenue                                4455.7
# Congress Heights                                4584.1
# Naylor Road                                     4659.3
# Stadium-Armory                                  4660.0
# West Falls Church                               5025.3
# ...

# %%
bottom_50_ridership_timeperiod_average_16 = ridership_timeperiod_average_16.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_ridership_timeperiod_average_16
# Out:
#                                        RIDERS_PER_WEEKDAY
# STATION               PERIOD
# Cheverly              Late Night Peak                0.50
# McLean                Late Night Peak                0.75
# Morgan Blvd.          Late Night Peak                0.75
# Greensboro            Late Night Peak                0.85
# Spring Hill           Late Night Peak                1.05
# Forest Glen           Late Night Peak                1.15
# West Falls Church     Late Night Peak                1.40
# Landover              Late Night Peak                1.40
# Arlington Cemetery    Late Night Peak                1.60
# Van Dorn Street       Late Night Peak                1.65
# Deanwood              Late Night Peak                1.80
# Pentagon              Late Night Peak                2.10
# Grosvenor             Late Night Peak                2.10
# Branch Avenue         Late Night Peak                2.10
# Capitol Heights       Late Night Peak                2.30
# ...

# %%
average_by_timeperiod_16 = ridership_timeperiod_16.groupby('PERIOD')[['RIDERS_PER_WEEKDAY']].mean()
average_by_timeperiod_16
# Out:
#                  RIDERS_PER_WEEKDAY
# PERIOD
# AM Peak                 2326.770879
# Evening                  726.488462
# Late Night Peak           16.408791
# Midday                  1229.867582
# PM Peak                 2469.426374

# %%
total_by_timeperiod_16 = ridership_timeperiod_16.groupby('PERIOD')[['RIDERS_PER_WEEKDAY']].sum()
total_by_timeperiod_16
# Out:
#                  RIDERS_PER_WEEKDAY
# PERIOD
# AM Peak                    423472.3
# Evening                    132220.9
# Late Night Peak              2986.4
# Midday                     223835.9
# PM Peak                    449435.6

# %% [markdown]
# Average and total ridership by Metro station for the overall 2010-2016 timeframe.

# %%
overall_ridership_average = ridership_data.groupby('STATION')[['RIDERS_PER_WEEKDAY']].mean()
overall_ridership_average
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Addison Road                               3330.172727
# Anacostia                                  7126.998485
# Archives-Navy Memorial                     8937.077273
# Arlington Cemetery                         1295.293939
# Ballston                                  11515.807576
# Benning Road                               3042.980303
# Bethesda                                  10332.924242
# Braddock Road                              4431.309091
# Branch Avenue                              6283.409091
# Brookland                                  6728.457576
# Capitol Heights                            2018.101515
# Capitol South                              8041.365152
# Cheverly                                   1430.410606
# Clarendon                                  4574.533333
# Cleveland Park                             4413.390909
# College Park-U of MD                       4531.748485
# ...

# %%
overall_ridership_total = ridership_data.groupby('STATION')[['RIDERS_PER_WEEKDAY']].sum()
overall_ridership_total
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Addison Road                                  219791.4
# Anacostia                                     470381.9
# Archives-Navy Memorial                        589847.1
# Arlington Cemetery                             85489.4
# Ballston                                      760043.3
# Benning Road                                  200836.7
# Bethesda                                      681973.0
# Braddock Road                                 292466.4
# Branch Avenue                                 414705.0
# Brookland                                     444078.2
# Capitol Heights                               133194.7
# Capitol South                                 530730.1
# Cheverly                                       94407.1
# Clarendon                                     301919.2
# Cleveland Park                                291283.8
# College Park-U of MD                          299095.4
# ...

# %%
top_50_stations_average = overall_ridership_average.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_stations_average
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Union Station                             31481.807576
# Metro Center                              27283.763636
# Gallery Place-Chinatown                   25895.813636
# Farragut North                            24265.968182
# Farragut West                             21778.980303
# Foggy Bottom                              21255.239394
# L'Enfant Plaza                            20265.175758
# Dupont Circle                             20246.119697
# Pentagon                                  15787.593939
# McPherson Square                          15756.046970
# Rosslyn                                   15460.854545
# Pentagon City                             15074.515152
# Shady Grove                               12889.995455
# Silver Spring                             12710.677273
# Crystal City                              12683.169697
# Vienna                                    12425.196970
# ...

# %%
top_50_stations_total = overall_ridership_total.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_stations_total
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Union Station                                2077799.3
# Metro Center                                 1800728.4
# Gallery Place-Chinatown                      1709123.7
# Farragut North                               1601553.9
# Farragut West                                1437412.7
# Foggy Bottom                                 1402845.8
# L'Enfant Plaza                               1337501.6
# Dupont Circle                                1336243.9
# Pentagon                                     1041981.2
# McPherson Square                             1039899.1
# Rosslyn                                      1020416.4
# Pentagon City                                 994918.0
# Shady Grove                                   850739.7
# Silver Spring                                 838904.7
# Crystal City                                  837089.2
# Vienna                                        820063.0
# ...

# %%
bottom_50_stations_average = overall_ridership_average.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_stations_average
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Greensboro                                  808.466667
# Spring Hill                                1076.072727
# McLean                                     1142.273077
# Arlington Cemetery                         1295.293939
# Cheverly                                   1430.410606
# Deanwood                                   1642.583333
# Eisenhower Avenue                          1852.722727
# Morgan Blvd.                               1950.483333
# Capitol Heights                            2018.101515
# Landover                                   2100.443939
# Tysons Corner                              2306.840000
# Forest Glen                                2329.180303
# Congress Heights                           2714.277273
# Stadium-Armory                             2848.821212
# Minnesota Avenue                           2888.478788
# Naylor Road                                2909.827273
# ...

# %%
bottom_50_stations_total = overall_ridership_total.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_stations_total
# Out:
#                                     RIDERS_PER_WEEKDAY
# STATION
# Greensboro                                     19403.2
# Spring Hill                                    23673.6
# McLean                                         29699.1
# Tysons Corner                                  57671.0
# Arlington Cemetery                             85489.4
# Cheverly                                       94407.1
# Deanwood                                      108410.5
# Eisenhower Avenue                             122279.7
# Morgan Blvd.                                  128731.9
# Capitol Heights                               133194.7
# Landover                                      138629.3
# Wiehle                                        151734.4
# Forest Glen                                   153725.9
# Congress Heights                              179142.3
# Stadium-Armory                                188022.2
# Minnesota Avenue                              190639.6
# ...

# %% [markdown]
# Overall average and total ridership for the entire 2010-2016 timeframe.

# %%
ridership_timeperiod_average = ridership_time.groupby(['STATION','PERIOD'])[['RIDERS_PER_WEEKDAY']].mean()
ridership_timeperiod_average
# Out:
#                                         RIDERS_PER_WEEKDAY
# STATION                PERIOD
# Addison Road           AM Peak                 2030.980303
#                        Evening                  198.065152
#                        Late Night Peak            5.240909
#                        Midday                   739.069697
#                        PM Peak                  360.913636
# Anacostia              AM Peak                 2923.171212
#                        Evening                  545.803030
#                        Late Night Peak           18.163636
#                        Midday                  1976.095455
#                        PM Peak                 1668.793939
# Archives-Navy Memorial AM Peak                  378.475758
#                        Evening                 1276.586364
#                        Late Night Peak           27.880303
#                        Midday                  1560.039394
# ...

# %%
ridership_timeperiod_total = ridership_time.groupby(['STATION','PERIOD'])[['RIDERS_PER_WEEKDAY']].sum()
ridership_timeperiod_total
# Out:
#                                         RIDERS_PER_WEEKDAY
# STATION                PERIOD
# Addison Road           AM Peak                    134044.7
#                        Evening                     13072.3
#                        Late Night Peak               345.9
#                        Midday                      48778.6
#                        PM Peak                     23820.3
# Anacostia              AM Peak                    192929.3
#                        Evening                     36023.0
#                        Late Night Peak              1198.8
#                        Midday                     130422.3
#                        PM Peak                    110140.4
# Archives-Navy Memorial AM Peak                     24979.4
#                        Evening                     84254.7
#                        Late Night Peak              1840.1
#                        Midday                     102962.6
# ...

# %%
top_50_stations_timeperiod_average = ridership_timeperiod_average.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_stations_timeperiod_average
# Out:
#                                  RIDERS_PER_WEEKDAY
# STATION                 PERIOD
# Metro Center            PM Peak        15144.433333
# Farragut North          PM Peak        15008.945455
# Farragut West           PM Peak        13216.854545
# L'Enfant Plaza          PM Peak        12583.054545
# Union Station           PM Peak        12170.333333
# Gallery Place-Chinatown PM Peak        11643.604545
# Foggy Bottom            PM Peak        10272.092424
# Union Station           AM Peak         9458.990909
# McPherson Square        PM Peak         9296.492424
# Shady Grove             AM Peak         8927.875758
# Vienna                  AM Peak         8734.522727
# Gallery Place-Chinatown Evening         7963.654545
# Dupont Circle           PM Peak         7811.612121
# Smithsonian             PM Peak         7192.436364
# Rosslyn                 PM Peak         6374.163636
# Pentagon                PM Peak         6222.160606
# ...

# %%
top_50_stations_timeperiod_total = ridership_timeperiod_total.sort_values('RIDERS_PER_WEEKDAY', ascending=False).head(50)
top_50_stations_timeperiod_total
# Out:
#                                  RIDERS_PER_WEEKDAY
# STATION                 PERIOD
# Metro Center            PM Peak            999532.6
# Farragut North          PM Peak            990590.4
# Farragut West           PM Peak            872312.4
# L'Enfant Plaza          PM Peak            830481.6
# Union Station           PM Peak            803242.0
# Gallery Place-Chinatown PM Peak            768477.9
# Foggy Bottom            PM Peak            677958.1
# Union Station           AM Peak            624293.4
# McPherson Square        PM Peak            613568.5
# Shady Grove             AM Peak            589239.8
# Vienna                  AM Peak            576478.5
# Gallery Place-Chinatown Evening            525601.2
# Dupont Circle           PM Peak            515566.4
# Smithsonian             PM Peak            474700.8
# Rosslyn                 PM Peak            420694.8
# Pentagon                PM Peak            410662.6
# ...

# %%
bottom_50_stations_timeperiod_average = ridership_timeperiod_average.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_stations_timeperiod_average
# Out:
#                                        RIDERS_PER_WEEKDAY
# STATION               PERIOD
# Greensboro            Late Night Peak            1.120000
# Arlington Cemetery    Late Night Peak            1.167742
# McLean                Late Night Peak            1.375000
# Spring Hill           Late Night Peak            1.785000
# Cheverly              Late Night Peak            1.822727
# Forest Glen           Late Night Peak            2.654545
# Landover              Late Night Peak            3.763636
# Branch Avenue         Late Night Peak            4.200000
# Deanwood              Late Night Peak            4.265152
# Wiehle                Late Night Peak            4.495000
# West Falls Church     Late Night Peak            4.539394
# Capitol Heights       Late Night Peak            4.559091
# Federal Center SW     Late Night Peak            4.565152
# Pentagon              Late Night Peak            4.689394
# Franconia-Springfield Late Night Peak            5.083333
# ...

# %%
bottom_50_stations_timeperiod_average = ridership_timeperiod_average.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_stations_timeperiod_average
# Out:
#                                        RIDERS_PER_WEEKDAY
# STATION               PERIOD
# Greensboro            Late Night Peak            1.120000
# Arlington Cemetery    Late Night Peak            1.167742
# McLean                Late Night Peak            1.375000
# Spring Hill           Late Night Peak            1.785000
# Cheverly              Late Night Peak            1.822727
# Forest Glen           Late Night Peak            2.654545
# Landover              Late Night Peak            3.763636
# Branch Avenue         Late Night Peak            4.200000
# Deanwood              Late Night Peak            4.265152
# Wiehle                Late Night Peak            4.495000
# West Falls Church     Late Night Peak            4.539394
# Capitol Heights       Late Night Peak            4.559091
# Federal Center SW     Late Night Peak            4.565152
# Pentagon              Late Night Peak            4.689394
# Franconia-Springfield Late Night Peak            5.083333
# ...

# %%
bottom_50_stations_timeperiod_total = ridership_timeperiod_total.sort_values('RIDERS_PER_WEEKDAY', ascending=True).head(50)
bottom_50_stations_timeperiod_total
# Out:
#                                        RIDERS_PER_WEEKDAY
# STATION               PERIOD
# Greensboro            Late Night Peak                22.4
# McLean                Late Night Peak                27.5
# Spring Hill           Late Night Peak                35.7
# Arlington Cemetery    Late Night Peak                36.2
# Wiehle                Late Night Peak                89.9
# Cheverly              Late Night Peak               120.3
# Forest Glen           Late Night Peak               175.2
# Tysons Corner         Late Night Peak               207.0
# Landover              Late Night Peak               248.4
# Branch Avenue         Late Night Peak               277.2
# Deanwood              Late Night Peak               281.5
# West Falls Church     Late Night Peak               299.6
# Capitol Heights       Late Night Peak               300.9
# Federal Center SW     Late Night Peak               301.3
# Pentagon              Late Night Peak               309.5
# ...

# %%
average_by_timeperiod = ridership_time.groupby('PERIOD')[['RIDERS_PER_WEEKDAY']].mean()
average_by_timeperiod
# Out:
#                  RIDERS_PER_WEEKDAY
# PERIOD
# AM Peak                 2614.038888
# Evening                  964.232848
# Late Night Peak           32.575631
# Midday                  1564.745781
# PM Peak                 2852.668004

# %%
total_by_timeperiod = ridership_time.groupby('PERIOD')[['RIDERS_PER_WEEKDAY']].sum()
total_by_timeperiod
# Out:
#                  RIDERS_PER_WEEKDAY
# PERIOD
# AM Peak                  15137899.2
# Evening                   5568444.7
# Late Night Peak            187016.7
# Midday                    9067701.8
# PM Peak                  16494126.4

# %% [markdown]
# CSV file exports.

# %%
#2014 ridership CSV files.

ridership_14.to_csv("Data/ridership_2014_data.csv")
top_50_ridership_14.to_csv("Data/top_50_ridership_2014.csv")
bottom_50_ridership_14.to_csv("Data/bottom_50_ridership_2014.csv")

# %%
#2015 ridership CSV files.

ridership_15.to_csv("Data/ridership_2015_data.csv")
top_50_ridership_15.to_csv("Data/top_50_rider_2015.csv")
bottom_50_ridership_15.to_csv("Data/bottom_50_ridership_2015.csv")

# %%
#2016 ridership CSV files.

ridership_16.to_csv("Data/ridership_2016_data.csv")
top_50_ridership_16.to_csv("Data/top_50_rider_2016.csv")
bottom_50_ridership_16.to_csv("Data/bottom_50_ridership_2016.csv")

# %%
#Ridership averages CSV files.

ridership_average_14.to_csv("Data/ridership_average_2014.csv")
ridership_average_15.to_csv("Data/ridership_average_2015.csv")
ridership_average_16.to_csv("Data/ridership_average_2016.csv")
overall_ridership_average.to_csv("Data/overall_ridership_average.csv")

# %%
#Ridership totals CSV files.

ridership_total_14.to_csv("Data/ridership_total_2014.csv")
ridership_total_15.to_csv("Data/ridership_total_2015.csv")
ridership_total_16.to_csv("Data/ridership_total_2016.csv")
overall_ridership_total.to_csv("Data/overall_ridership_total.csv")

# %%
#Ridership by time period averages CSV files.

ridership_timeperiod_average_14.to_csv("Data/ridership_timeperiod_average_2014.csv")
ridership_timeperiod_average_15.to_csv("Data/ridership_timeperiod_average_2015.csv")
ridership_timeperiod_average_16.to_csv("Data/ridership_timeperiod_average_2016.csv")
ridership_timeperiod_average.to_csv("Data/overall_ridership_timeperiod_average")
average_by_timeperiod.to_csv("Data/timeperiod_average.csv")

# %%
#Ridership by time period totals CSV files.

ridership_timeperiod_total_14.to_csv("Data/ridership_timeperiod_totals_2014.csv")
ridership_timeperiod_total_15.to_csv("Data/ridership_timeperiod_totals_2015.csv")
ridership_timeperiod_total_16.to_csv("Data/ridership_timeperiod_totals_2016.csv")
ridership_timeperiod_total.to_csv("Data/overall_ridership_timperiod_total.csv")
total_by_timeperiod.to_csv("Data/timeperiod_total.csv")

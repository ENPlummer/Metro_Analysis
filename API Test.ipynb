# %%
import http.client, urllib.request, urllib.parse, urllib.error, base64
import pandas as pd
from pandas.io.json import json_normalize

# %%
headers = {
    # Request headers
    'api_key': 'e7e5936db51241acb876e827aa8639ae',
}

params = urllib.parse.urlencode({
})

try:
    conn = http.client.HTTPSConnection('api.wmata.com')
    conn.request("GET", "/StationPrediction.svc/json/GetPrediction/All?%s" % params, "{body}", headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))
# Out:
# b'{"Trains":[{"Car":"8","Destination":"Shady Gr","DestinationCode":"A15","DestinationName":"Shady Grove","Group":"2","Line":"RD","LocationCode":"A04","LocationName":"Woodley Park-Zoo/Adams Morgan","Min":"BRD"},{"Car":"8","Destination":"Shady Gr","DestinationCode":"A15","DestinationName":"Shady Grove","Group":"2","Line":"RD","LocationCode":"A10","LocationName":"Medical Center","Min":"BRD"},{"Car":"8","Destination":"Glenmont","DestinationCode":"B11","DestinationName":"Glenmont","Group":"1","Line":"RD","LocationCode":"B03","LocationName":"Union Station","Min":"BRD"},{"Car":"6","Destination":"Shady Gr","DestinationCode":"A15","DestinationName":"Shady Grove","Group":"2","Line":"RD","LocationCode":"B03","LocationName":"Union Station","Min":"BRD"},{"Car":"6","Destination":"Shady Gr","DestinationCode":"A15","DestinationName":"Shady Grove","Group":"2","Line":"RD","LocationCode":"B06","LocationName":"Fort Totten","Min":"BRD"},{"Car":"6","Destination":"Glenmont","DestinationCode":"B11","DestinationName":"Glenmont","Group":"1","Line":"RD","LocationCode":"B10","LocationName":"Wheaton","Min":"BRD"},{"Car":"6","Destination":"Shady Gr","DestinationCode":"A15","DestinationName":"Shady Grove","Group":"2","Line":"RD","LocationCode":"B10","LocationName":"Wheaton","Min":"BRD"},{"Car":"6","Destination":"Ft.Tottn","DestinationCode":"E06","DestinationName":"Fort Totten","Group":"1","Line":"YL","LocationCode":"C09","LocationName":"Crystal City","Min":"BRD"},{"Car":"6","Destination":"Hntingtn","DestinationCode":"C15","DestinationName":"Huntington","Group":"2","Line":"YL","LocationCode":"C10","LocationName":"Ronald Reagan Washington National Airport","Min":"BRD"},{"Car":"6","Destination":"Ft.Tottn","DestinationCode":"E06","DestinationName":"Fort Totten","Group":"1","Line":"YL","LocationCode":"C14","LocationName":"Eisenhower Avenue","Min":"BRD"},{"Car":"6","Destination":"Largo","DestinationCode":"G05","DestinationName":"Largo Town Center","Group":"1","Line":"SV","LocationCode":"G04","LocationName":"Morgan Boulevard","Min":"BRD"},{"Car":"6","Destination":"Frnconia","DestinationCode":"J03","DestinationName":"Franconia-Springfield","Group":"2","Line":"BL","LocationCode":"D02","LocationName":"Smithsonian","Min":"BRD"},{"Car":"6","Destination":"Largo","DestinationCode":"G05","DestinationName":"Largo Town Center","Group":"1","Line":"BL","LocationCode":"D03","LocationName":"L\'Enfant Plaza","Min":"BRD"},{"Car":"8","Destination":"Vienna","DestinationCode":"K08","DestinationName":"Vienna/Fairfax-GMU","Group":"2","Line":"OR","LocationCode":"D05","LocationName":"Capitol South","Min":"BRD"},{"Car":"6","Destination":"Largo","DestinationCode":"G05","DestinationName":"Largo Town Center","Group":"1","Line":"SV","LocationCode":"D06","LocationName":"Eastern Market","Min":"BRD"},{"Car":"6","Destination":"Wiehle","DestinationCode":"N06","DestinationName":"Wiehle-Reston East","Group":"2","Line":"SV","LocationCode":"D08","LocationName":"Stadium-Armory","Min":"BRD"},{"Car":"8","Destination":"Grnbelt","DestinationCode":"E10","DestinationName":"Greenbelt","Group":"1","Line":"GR","LocationCode":"E06","LocationName":"Fort Totten","Min":"BRD"},{"Car":"6","Destination":"Hntingtn","DestinationCode":"C15","DestinationName":"Huntington","Group":"2","Line":"YL","LocationCode":"E06","LocationName":"Fort Totten","Min":"BRD"},{"Car":"6","Destination":"Ft.Tottn","DestinationCode":"E06","DestinationName":"Fort Totten","Group":"1","Line":"YL","LocationCode":"F01","LocationName":"Gallery Pl-Chinatown","Min":"BRD"},{"Car":"6","Destination":"Hntingtn","DestinationCode":"C15","DestinationName":"Huntington","Group":"2","Line":"YL","LocationCode":"F02","LocationName":"Archives-Navy Memorial-Penn Quarter","Min":"BRD"},{"Car":"8","Destination":"Grnbelt","DestinationCode":"E10","DestinationName":"Greenbelt","Group":"1","Line":"GR","LocationCode":"F05","LocationName":"Navy Yard-Ballpark","Min":"BRD"},{"Car":"6","Destination":"Grnbelt","DestinationCode":"E10","DestinationName":"Greenbelt","Group":"1","L ...

# %%
import json
j = json.loads(data)
print(j["Trains"][0])
# Out:
# {'Car': '8', 'Destination': 'Shady Gr', 'DestinationCode': 'A15', 'DestinationName': 'Shady Grove', 'Group': '2', 'Line': 'RD', 'LocationCode': 'A04', 'LocationName': 'Woodley Park-Zoo/Adams Morgan', 'Min': 'BRD'}

# %%
metro_lines = json.normalize(metro_pd)
metro_lines
